# %%
#@title Install conda
import sys

CONDA="Miniconda3-py37_22.11.1-1-Linux-x86_64.sh"
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
# !wget "https://repo.continuum.io/miniconda"/$CONDA -O ./$CONDA
# !chmod +x ./$CONDA
# !bash ./$CONDA -b -f -p /usr/local

sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2024-03-21 06:56:50--  https://repo.continuum.io/miniconda/Miniconda3-py37_22.11.1-1-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.16.245.55, 104.16.246.55, 2606:4700::6810:f537, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.16.245.55|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py37_22.11.1-1-Linux-x86_64.sh [following]
# --2024-03-21 06:56:50--  https://repo.anaconda.com/miniconda/Miniconda3-py37_22.11.1-1-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86308321 (82M) [application/x-sh]
# Saving to: ‘./Miniconda3-py37_22.11.1-1-Linux-x86_64.sh’
#
# ./Miniconda3-py37_2 100%[===================>]  82.31M   204MB/s    in 0.4s
#
# ...

# %%
# !conda init bash
# !conda create --name tabsurvey python=3.7
# !conda activate tabsurvey
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.7/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.11.1
#   latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# ...

# %%
import os
os.environ['CONDA_PREFIX'] = '/usr/local/envs/tabsurvey'

# %%
#@title Upload TabSurvey
from google.colab import drive
drive.mount('/content/drive')

import shutil
source_dir = '/content/drive/MyDrive/IECLearning_Shared/TabSurvey'
destination_dir = '/content/TabSurvey'

shutil.copytree(source_dir, destination_dir, dirs_exist_ok=True)
# Out:
# Mounted at /content/drive
# '/content/TabSurvey'

# %%
# !pip install protobuf==3.19.6

# %%
# %cd TabSurvey
# !pip install -r requirements.txt
# !sudo apt-get install dos2unix
# !dos2unix testall.sh
# Out:
# /content/TabSurvey
# ...
#      - 30.7 kB 1.1 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      \ 5.9 MB 13.7 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 34.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 50.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.5/411.5 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.6/255.9 MB 2.3 MB/s eta 0:01:39

# %%
# !bash testall.sh
# Out:
# ----------------------------------------------------------------------------
# Training LinearModel with config/CICMalMem2022.yml
# Train model with given hyperparameters
# Loading dataset CICMalMem2022...
# Dataset loaded!
# (58047, 52)
# Scaling the data...
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# ------------------------
# TPR-weight: 99.8966
# PPV-weight: 99.8967
# F1-weight : 99.8966
# MCC-func  : 0.9979
# AUC-func  : 0.9990
# ...

# %%
# #@title Save Lib
# import shutil
# source_dir = '/content/TabSurvey'
# destination_dir = '/content/drive/MyDrive/IECLearning_Shared/TabSurvey'

# shutil.copytree(source_dir, destination_dir, dirs_exist_ok=True)

# %%
# import pandas as pd
# pd.read_csv('/content/report_tabsurvey.csv')
# Out:
#              Name         Model  MCC - mean  ACC - mean  TPR - mean  \
# 0   CICMalMem2022   LinearModel    0.998105   99.905250   99.895892
# 1   CICMalMem2022           KNN    0.992871   99.643392   99.531510
# 2   CICMalMem2022  DecisionTree    0.999655   99.982772   99.986118
# 3   CICMalMem2022  RandomForest    0.999759   99.987941   99.996530
# 4   CICMalMem2022       XGBoost    0.999070   99.953486   99.920183
# 5   CICMalMem2022      CatBoost    0.997968   99.898359   99.941008
# 6   CICMalMem2022      LightGBM    0.997968   99.898359   99.826489
# 7   CICMalMem2022           MLP    0.998346   99.917308   99.954886
# 8   CICMalMem2022       DeepGBM    0.000000   49.642531  100.000000
# 9   CICMalMem2022        DeepFM    0.997692   99.884576   99.902831
# 10  CICMalMem2022         SAINT    0.957410   97.744857   95.863268
#
#     FPR - mean  F1 - mean  TPR weight - mean  PPV weight - mean  \
# 0     0.085527  99.904558          99.905250          99.905269
# ...
