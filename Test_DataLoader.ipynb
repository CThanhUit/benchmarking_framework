# %%
# %pip install -r  "DataLoader/requirements.txt"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # DataLoader

# %%
import DataLoader
from DataLoader import BaseLoadDataset

# %%
a = BaseLoadDataset(dataset_name="CICMalMem2022", print_able=True)
# Out:
# =================================== Show dataset metadata ===================================
# Dataset name: CICMalMem2022
# Original public at paper: https://www.unb.ca/cic/datasets/malmem-2022.html
# Dataset link: http://clouds.iec-uit.com/iec-iot-2021.idsdatasets/CICMalMem2022.zip
# Total size on disk (MB): None
# Total  57 features:
# ...

# %%
dataset_dir = "D:/Hoc_tap/IEC/Code/benchmarking_framework"

# %%
a.DownLoad_Data(datadir=dataset_dir, load_type="raw")
# Out:
# Attention !!! Your chosen dataset will take None MB in local storage. Use Ctrl+C to abort before the process start.
# ======================== Folder Data not found!!! Start downloading ========================
# ======================== File Data Zip not found!!! Start downloading ======================
# Start download file - Total file_size: 3786865
# 100%|██████████| 3.61M/3.61M [00:00<00:00, 5.35MB/s]
# File saved at: D:\Hoc_tap\IEC\Code\benchmarking_framework\CICMalMem2022.zip
# ===================================== End download data ====================================
# ====================================== Unzipping Data!!! ===================================
# 100%|██████████| 1/1 [00:00<00:00, 14.25it/s]
# File saved at: D:/Hoc_tap/IEC/Code/benchmarking_framework
# ===================================== End download data ====================================

# %%
a.Load_Data(datadir=dataset_dir, load_type="raw")
# Out:
# ====================================== Start load data =======================================
# Begin file Obfuscated-MalMem2022.csv
# Update label:
# {'Benign': 29298, 'Ransomware-Conti': 1988, 'Ransomware-Ako': 2000, 'Spyware-180solutions': 2000, 'Spyware-CWS': 2000, 'Ransomware-Maze': 1958, 'Ransomware-Pysa': 1717, 'Spyware-Gator': 2200, 'Ransomware-Shade': 2128, 'Spyware-Transponder': 2410, 'Trojan-Emotet': 1967, 'Trojan-Reconyc': 1570, 'Spyware-TIBS': 1410, 'Trojan-Refroso': 2000, 'Trojan-Scar': 2000, 'Trojan-Zeus': 1950}
# Time load: 1712039671.1360087 1712039670.6637237
# ========================== Finish Obfuscated-MalMem2022.csv =================================
# Total time load: 0.4742848873138428
# ======================================== Data loaded =========================================

# %%
a.Show_basic_metadata()
# Out:
# =================================== Show dataset metadata ===================================
# Dataset name: CICMalMem2022
# Original public at paper: https://www.unb.ca/cic/datasets/malmem-2022.html
# Dataset link: http://clouds.iec-uit.com/iec-iot-2021.idsdatasets/CICMalMem2022.zip
# Total size on disk (MB): None
# Total  57 features:
# ...

# %%
a.Show_basic_analysis()
# Out:
# ============================= Show basic analysis of data frame ==============================
# ====================================== Dataframe be like =====================================
#
# ...

# %%
a.To_csv()
# Out:
# File saved at: d:\Hoc_tap\IEC\Code\benchmarking_framework\CICMalMem2022_dataloader.csv

# %%
df = a.To_dataframe()

# %%
df
# Out:
#               Category  pslist.nproc  pslist.nppid  pslist.avg_threads  \
# 0               Benign            42            12           12.904762
# 1               Benign            40            12           13.200000
# 2               Benign            55            20           11.067154
# 3               Benign            39            12           12.974359
# 4               Benign            40            12           13.375000
# ...                ...           ...           ...                 ...
# 58591  Ransomware-Pysa            37            15           10.135135
# 58592  Ransomware-Pysa            37            15           10.270270
# 58593  Ransomware-Pysa            40            16            9.850000
# 58594  Ransomware-Pysa            40            16            9.600000
# 58595  Ransomware-Pysa            42            17            9.285714
#
#        pslist.nprocs64bit  pslist.avg_handlers  dlllist.ndlls  \
# ...
